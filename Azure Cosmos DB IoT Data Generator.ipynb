# %% [markdown]
# # Azure Cosmos DB IoT Data Generator
#
# By Rodrigo Souza
#
# Last Updated on Feb 2024

# %%
###########################################################################################
# Environment
###########################################################################################

import random # to create random IoT measures based on random variations
import datetime
import time
import azure.cosmos.exceptions as exceptions
from azure.cosmos.partition_key import PartitionKey
import uuid # to create an unique id for each data point
import warnings 
from azure.cosmos import CosmosClient
import os

DATABASE_NAME = ''
DEVICES_CONTAINER_NAME = ''
CONTAINER_NAME = ''
URL=''
KEY= ''

# Client
client = CosmosClient(URL, credential=KEY)

# Database
try:
    database = client.create_database(DATABASE_NAME)
except exceptions.CosmosResourceExistsError:
    database = client.get_database_client(DATABASE_NAME)


# Container for IoT Devices 
try:
    container = database.create_container(id=DEVICES_CONTAINER_NAME, partition_key=PartitionKey(path="/id"))
except exceptions.CosmosResourceExistsError:
    container = database.get_container_client(DEVICES_CONTAINER_NAME)
except exceptions.CosmosHttpResponseError:
    raise

# Container for IoT Devices 
try:
    container = database.create_container(id=CONTAINER_NAME, partition_key=PartitionKey(path="/id"))
except exceptions.CosmosResourceExistsError:
    container = database.get_container_client(CONTAINER_NAME)
except exceptions.CosmosHttpResponseError:
    raise

# %%
###########################################################################################
# The function that creates and returns IoT values
###########################################################################################
from datetime import datetime

def RetunrIotValues(deviceId, measureType, unitSymbol, unit, baseValue, variationPercentage, isOutlier, outlierSignal):
    if (isOutlier == 0):
        value = random.randint(int(baseValue - (baseValue * (variationPercentage)/100)), int(baseValue + (baseValue * (variationPercentage)/100 )))
    else: #Outlier!    
        variationPercentage = int(variationPercentage*1.3) # 30% bigger Variation
        if (outlierSignal == 'Positive'):
            baseValue = int(baseValue*1.3) # 30% bigger base value
            value = random.randint(int(baseValue), int(baseValue + (baseValue * (variationPercentage)/100 )))
        else:
            baseValue = int(baseValue *0.7) # 30% smaller base value
            value = random.randint(int(baseValue - (baseValue * (variationPercentage)/100)), int(baseValue))

    docId = str(uuid.uuid4())
    latitude = str(value)+'.35.60'
    longitude = str(value+20)+'.35.60'

    IotData = {
    'id' : docId,
    'dateTime' : datetime.now().strftime("%Y-%m-%dT%H:%M:%SZ"),
    'deviceId' : deviceId,
    'measureType' : measureType,
    'unitSymbol' : unitSymbol,
    'unit' : unit,
    'measureValue' : value,
    'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA',
    'deviceModel': measureType+'_001',
    'deviceVersion': 'June, 2023',
    'deviceLatitude': latitude,
    'deviceLongitude': longitude,
    'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.',
    'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'
    }

    return IotData


print('Function RetunrIotValues ok')
# Out:
# Function RetunrIotValues ok

# %%
###########################################################################################
# Function to detect prime numbers to create different cities based on the device suffix
###########################################################################################
def isprime(num):
    for n in range(2,int(num**0.5)+1):
        if num%n==0:
            return False
    return True

# %%
###########################################################################################
# The IoT function for devices and values/measures
###########################################################################################
def IotSimulator(numDevs=20, minutes=1,generateDevices=1 ,printOutput=0): 


    # Creates Devices list and also populates the Devices Container, starting with dev-1
    if (generateDevices == 1):
        container = database.get_container_client(DEVICES_CONTAINER_NAME)
    devPrefix = 'dev-'
    devicesList = [ ] 
    print ('Starting to create Devices')
    for i in range(1,numDevs+1):
        deviceId = devPrefix + str(i)
        if (generateDevices == 1):
            devId = str(uuid.uuid4())
            if (int(i)%2==0):
                City='Rio de Janeiro'
            else:
                if (isprime(int(i)) ):
                    City='New York'
                else:
                    City='Seattle'
            IoTDevice = {'id': devId,'deviceId':deviceId,'city':City}
            if (printOutput == 1):
                print ('Creating Device: ',IoTDevice)
            container.upsert_item(body=IoTDevice)
        devicesList.append(deviceId)

    # Units list
    unitList = [('Rotation Speed','RPM','Revolutions per Minute',3000,10, 'Positive'), ('Output','MW','MegaWatts',1500,10,'Negative')]

    # How many measures based on the number per minutes?
    numberMeasures = int(minutes)*60 
    accNumberMeasures = 0
    
    # Outliers
    accOutliers = 0
    ouliersSet = set()
    while len(ouliersSet) < int(minutes):
        outlier = random.randint(1, int(minutes)*60)
        ouliersSet.add(outlier)
    print ('Starting the process. The random outlier(s) will happen at these seconds: ',ouliersSet)
    
    # Create IoT Values based on a base value and a variation. Every device will return 1 value per unit per second.
    # Data is printed and saved into a Cosmos DB Container
    # Data modeling: We could have one document per device. But this approach is addressed in the data modeling notebook.
    container = database.get_container_client(CONTAINER_NAME)

    while (accNumberMeasures <= numberMeasures):
        #time.sleep(1)
        for deviceId in devicesList:
            for unit in unitList:
                if (accNumberMeasures in ouliersSet):  # If yes, time for an outlier
                    IotData = RetunrIotValues (deviceId,unit[0],unit[1],unit[2],unit[3],unit[4],1,unit[5])
                    print('Outlier:',deviceId,unit[2])
                else: # Regular measure
                    IotData = RetunrIotValues (deviceId,unit[0],unit[1],unit[2],unit[3],unit[4],0,unit[5])
                container.upsert_item(body=IotData)
                if (printOutput == 1):
                    print(IotData)
        accNumberMeasures +=1 

        
print ('Function iotSimulator ok')
# Out:
# Function iotSimulator ok

# %%
numDevs=10000
executionMinutes=10
printOutput=1
generateDevices=0
IotSimulator (numDevs,executionMinutes,generateDevices,printOutput)
# Out:
# Starting to create Devices
# Starting the process. The random outlier(s) will happen at these seconds:  {393, 42, 235, 269, 465, 178, 115, 375, 124, 125}
# {'id': '0f401595-00ad-4604-aa3c-e12ef4afd9f6', 'dateTime': '2024-02-13T10:46:24Z', 'deviceId': 'dev-1', 'measureType': 'Rotation Speed', 'unitSymbol': 'RPM', 'unit': 'Revolutions per Minute', 'measureValue': 3144, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Rotation Speed_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '3144.35.60', 'deviceLongitude': '3164.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': '159922a5-f4c7-4233-8fb8-8201734895c1', 'dateTime': '2024-02-13T10:46:25Z', 'deviceId': 'dev-1', 'measureType': 'Output', 'unitSymbol': 'MW', 'unit': 'MegaWatts', 'measureValue': 1612, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Output_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '1612.35.60', 'deviceLongitude': '1632.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': '562538f2-7879-4725-9f90-21ce3435368f', 'dateTime': '2024-02-13T10:46:25Z', 'deviceId': 'dev-2', 'measureType': 'Rotation Speed', 'unitSymbol': 'RPM', 'unit': 'Revolutions per Minute', 'measureValue': 3161, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Rotation Speed_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '3161.35.60', 'deviceLongitude': '3181.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': '6effc67c-34ae-4b4a-a438-911feaaf09cc', 'dateTime': '2024-02-13T10:46:25Z', 'deviceId': 'dev-2', 'measureType': 'Output', 'unitSymbol': 'MW', 'unit': 'MegaWatts', 'measureValue': 1350, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Output_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '1350.35.60', 'deviceLongitude': '1370.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': 'b5792f4d-20de-4760-9b3e-53550ac9558b', 'dateTime': '2024-02-13T10:46:25Z', 'deviceId': 'dev-3', 'measureType': 'Rotation Speed', 'unitSymbol': 'RPM', 'unit': 'Revolutions per Minute', 'measureValue': 2975, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Rotation Speed_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '2975.35.60', 'deviceLongitude': '2995.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': '89a223f8-fff8-4c94-ba70-fb18e59a0a1c', 'dateTime': '2024-02-13T10:46:25Z', 'deviceId': 'dev-3', 'measureType': 'Output', 'unitSymbol': 'MW', 'unit': 'MegaWatts', 'measureValue': 1495, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Output_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '1495.35.60', 'deviceLongitude': '1515.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': '26000e7b-8e48-4701-9637-8bec3b3c0a39', 'dateTime': '2024-02-13T10:46:25Z', 'deviceId': 'dev-4', 'measureType': 'Rotation Speed', 'unitSymbol': 'RPM', 'unit': 'Revolutions per Minute', 'measureValue': 3268, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Rotation Speed_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '3268.35.60', 'deviceLongitude': '3288.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': '5de1d849-93bf-4077-bf04-9e454dd83f2a', 'dateTime': '2024-02-13T10:46:25Z', 'deviceId': 'dev-4', 'measureType': 'Output', 'unitSymbol': 'MW', 'unit': 'MegaWatts', 'measureValue': 1441, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Output_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '1441.35.60', 'deviceLongitude': '1461.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': 'cc63c832-23fb-4f6c-b128-6c855b47d840', 'dateTime': '2024-02-13T10:46:25Z', 'deviceId': 'dev-5', 'measureType': 'Rotation Speed', 'unitSymbol': 'RPM', 'unit': 'Revolutions per Minute', 'measureValue': 3066, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Rotation Speed_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '3066.35.60', 'deviceLongitude': '3086.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': 'e4a3e118-4254-48a7-9372-cb7281e4e8f4', 'dateTime': '2024-02-13T10:46:25Z', 'deviceId': 'dev-5', 'measureType': 'Output', 'unitSymbol': 'MW', 'unit': 'MegaWatts', 'measureValue': 1635, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Output_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '1635.35.60', 'deviceLongitude': '1655.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': 'f2d886a2-a940-4e32-9b1d-43c00d256d8f', 'dateTime': '2024-02-13T10:46:25Z', 'deviceId': 'dev-6', 'measureType': 'Rotation Speed', 'unitSymbol': 'RPM', 'unit': 'Revolutions per Minute', 'measureValue': 2812, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Rotation Speed_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '2812.35.60', 'deviceLongitude': '2832.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': '496087ba-71a8-4fdc-869a-736c7fc812df', 'dateTime': '2024-02-13T10:46:25Z', 'deviceId': 'dev-6', 'measureType': 'Output', 'unitSymbol': 'MW', 'unit': 'MegaWatts', 'measureValue': 1530, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Output_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '1530.35.60', 'deviceLongitude': '1550.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': 'e6b3b5d6-8ca7-4975-af5e-821fdc95411e', 'dateTime': '2024-02-13T10:46:25Z', 'deviceId': 'dev-7', 'measureType': 'Rotation Speed', 'unitSymbol': 'RPM', 'unit': 'Revolutions per Minute', 'measureValue': 2712, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Rotation Speed_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '2712.35.60', 'deviceLongitude': '2732.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': 'e50c0e5c-1a3a-4970-a6b9-b4666b229dbb', 'dateTime': '2024-02-13T10:46:25Z', 'deviceId': 'dev-7', 'measureType': 'Output', 'unitSymbol': 'MW', 'unit': 'MegaWatts', 'measureValue': 1381, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Output_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '1381.35.60', 'deviceLongitude': '1401.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': 'bb316503-60e8-42e0-a5d4-d6b20889961b', 'dateTime': '2024-02-13T10:46:25Z', 'deviceId': 'dev-8', 'measureType': 'Rotation Speed', 'unitSymbol': 'RPM', 'unit': 'Revolutions per Minute', 'measureValue': 2768, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Rotation Speed_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '2768.35.60', 'deviceLongitude': '2788.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': '8234f81f-5f22-4edf-9724-451eef3904f9', 'dateTime': '2024-02-13T10:46:25Z', 'deviceId': 'dev-8', 'measureType': 'Output', 'unitSymbol': 'MW', 'unit': 'MegaWatts', 'measureValue': 1453, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Output_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '1453.35.60', 'deviceLongitude': '1473.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': '7b01b796-c9fd-47b2-b987-572cd34c0a56', 'dateTime': '2024-02-13T10:46:25Z', 'deviceId': 'dev-9', 'measureType': 'Rotation Speed', 'unitSymbol': 'RPM', 'unit': 'Revolutions per Minute', 'measureValue': 2836, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Rotation Speed_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '2836.35.60', 'deviceLongitude': '2856.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': '55262e54-98d1-4098-87d4-82dc29984a6e', 'dateTime': '2024-02-13T10:46:25Z', 'deviceId': 'dev-9', 'measureType': 'Output', 'unitSymbol': 'MW', 'unit': 'MegaWatts', 'measureValue': 1593, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Output_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '1593.35.60', 'deviceLongitude': '1613.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': 'df48fd66-d078-4af1-9a3a-cf536ee7720f', 'dateTime': '2024-02-13T10:46:25Z', 'deviceId': 'dev-10', 'measureType': 'Rotation Speed', 'unitSymbol': 'RPM', 'unit': 'Revolutions per Minute', 'measureValue': 2778, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Rotation Speed_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '2778.35.60', 'deviceLongitude': '2798.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': 'f4e55e43-8c1e-4ba7-b831-72c83dddbf1b', 'dateTime': '2024-02-13T10:46:25Z', 'deviceId': 'dev-10', 'measureType': 'Output', 'unitSymbol': 'MW', 'unit': 'MegaWatts', 'measureValue': 1351, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Output_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '1351.35.60', 'deviceLongitude': '1371.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': '14c0e77a-82db-41b9-bd0b-23602af9885c', 'dateTime': '2024-02-13T10:46:25Z', 'deviceId': 'dev-11', 'measureType': 'Rotation Speed', 'unitSymbol': 'RPM', 'unit': 'Revolutions per Minute', 'measureValue': 3095, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Rotation Speed_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '3095.35.60', 'deviceLongitude': '3115.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': '6324850c-3cb0-4042-a8c8-86046c608440', 'dateTime': '2024-02-13T10:46:26Z', 'deviceId': 'dev-11', 'measureType': 'Output', 'unitSymbol': 'MW', 'unit': 'MegaWatts', 'measureValue': 1479, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Output_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '1479.35.60', 'deviceLongitude': '1499.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': '6b3a4304-fd07-4489-8bfb-01b762443a50', 'dateTime': '2024-02-13T10:46:26Z', 'deviceId': 'dev-12', 'measureType': 'Rotation Speed', 'unitSymbol': 'RPM', 'unit': 'Revolutions per Minute', 'measureValue': 2743, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Rotation Speed_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '2743.35.60', 'deviceLongitude': '2763.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': '94bbcbd7-3f38-444b-ad13-ca4e4a26cf60', 'dateTime': '2024-02-13T10:46:26Z', 'deviceId': 'dev-12', 'measureType': 'Output', 'unitSymbol': 'MW', 'unit': 'MegaWatts', 'measureValue': 1440, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Output_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '1440.35.60', 'deviceLongitude': '1460.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': 'f50d2e74-0d8f-46cf-8cfd-07bcf8d6da08', 'dateTime': '2024-02-13T10:46:26Z', 'deviceId': 'dev-13', 'measureType': 'Rotation Speed', 'unitSymbol': 'RPM', 'unit': 'Revolutions per Minute', 'measureValue': 3090, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Rotation Speed_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '3090.35.60', 'deviceLongitude': '3110.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': '457f8c19-ce96-4092-b67f-0e5bd56cd6d7', 'dateTime': '2024-02-13T10:46:26Z', 'deviceId': 'dev-13', 'measureType': 'Output', 'unitSymbol': 'MW', 'unit': 'MegaWatts', 'measureValue': 1560, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Output_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '1560.35.60', 'deviceLongitude': '1580.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': 'e4f36645-f060-4613-8acf-8cffd79b60a9', 'dateTime': '2024-02-13T10:46:26Z', 'deviceId': 'dev-14', 'measureType': 'Rotation Speed', 'unitSymbol': 'RPM', 'unit': 'Revolutions per Minute', 'measureValue': 3285, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Rotation Speed_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '3285.35.60', 'deviceLongitude': '3305.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': '2c40db24-101b-40d3-a253-14e60afea603', 'dateTime': '2024-02-13T10:46:26Z', 'deviceId': 'dev-14', 'measureType': 'Output', 'unitSymbol': 'MW', 'unit': 'MegaWatts', 'measureValue': 1435, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Output_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '1435.35.60', 'deviceLongitude': '1455.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': '98429a56-6057-40c2-845f-6fe4b86adfc6', 'dateTime': '2024-02-13T10:46:26Z', 'deviceId': 'dev-15', 'measureType': 'Rotation Speed', 'unitSymbol': 'RPM', 'unit': 'Revolutions per Minute', 'measureValue': 3182, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Rotation Speed_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '3182.35.60', 'deviceLongitude': '3202.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': '946fc974-74e6-4930-aa3d-82aaeb7b9474', 'dateTime': '2024-02-13T10:46:26Z', 'deviceId': 'dev-15', 'measureType': 'Output', 'unitSymbol': 'MW', 'unit': 'MegaWatts', 'measureValue': 1393, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Output_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '1393.35.60', 'deviceLongitude': '1413.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': 'c83b31a4-2289-4794-9747-ff485002e154', 'dateTime': '2024-02-13T10:46:26Z', 'deviceId': 'dev-16', 'measureType': 'Rotation Speed', 'unitSymbol': 'RPM', 'unit': 'Revolutions per Minute', 'measureValue': 3138, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Rotation Speed_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '3138.35.60', 'deviceLongitude': '3158.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': '31b5281b-accc-4465-9a9b-d6cab07f7f28', 'dateTime': '2024-02-13T10:46:26Z', 'deviceId': 'dev-16', 'measureType': 'Output', 'unitSymbol': 'MW', 'unit': 'MegaWatts', 'measureValue': 1620, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Output_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '1620.35.60', 'deviceLongitude': '1640.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': '459c7c71-875e-4176-a5c7-a8d7d164d8be', 'dateTime': '2024-02-13T10:46:26Z', 'deviceId': 'dev-17', 'measureType': 'Rotation Speed', 'unitSymbol': 'RPM', 'unit': 'Revolutions per Minute', 'measureValue': 2843, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Rotation Speed_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '2843.35.60', 'deviceLongitude': '2863.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': 'fbbbfa09-7e60-4c05-b85a-8ff8fd431c29', 'dateTime': '2024-02-13T10:46:26Z', 'deviceId': 'dev-17', 'measureType': 'Output', 'unitSymbol': 'MW', 'unit': 'MegaWatts', 'measureValue': 1411, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Output_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '1411.35.60', 'deviceLongitude': '1431.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': '82648509-67f4-409b-a297-e2655dbba877', 'dateTime': '2024-02-13T10:46:26Z', 'deviceId': 'dev-18', 'measureType': 'Rotation Speed', 'unitSymbol': 'RPM', 'unit': 'Revolutions per Minute', 'measureValue': 2980, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Rotation Speed_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '2980.35.60', 'deviceLongitude': '3000.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': 'c554e443-3cca-4fd9-b4da-ed689721b693', 'dateTime': '2024-02-13T10:46:26Z', 'deviceId': 'dev-18', 'measureType': 'Output', 'unitSymbol': 'MW', 'unit': 'MegaWatts', 'measureValue': 1469, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Output_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '1469.35.60', 'deviceLongitude': '1489.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': '453d2e07-151c-40f3-b658-63c5ec0056b9', 'dateTime': '2024-02-13T10:46:26Z', 'deviceId': 'dev-19', 'measureType': 'Rotation Speed', 'unitSymbol': 'RPM', 'unit': 'Revolutions per Minute', 'measureValue': 2981, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Rotation Speed_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '2981.35.60', 'deviceLongitude': '3001.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': '2aa18a25-dcdd-49ca-9ef9-2c465382eb42', 'dateTime': '2024-02-13T10:46:26Z', 'deviceId': 'dev-19', 'measureType': 'Output', 'unitSymbol': 'MW', 'unit': 'MegaWatts', 'measureValue': 1406, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Output_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '1406.35.60', 'deviceLongitude': '1426.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': 'a2427212-c23c-4172-9977-417cd4937c7b', 'dateTime': '2024-02-13T10:46:26Z', 'deviceId': 'dev-20', 'measureType': 'Rotation Speed', 'unitSymbol': 'RPM', 'unit': 'Revolutions per Minute', 'measureValue': 2814, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Rotation Speed_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '2814.35.60', 'deviceLongitude': '2834.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': 'f2793116-2285-4146-bfdf-d191823987df', 'dateTime': '2024-02-13T10:46:26Z', 'deviceId': 'dev-20', 'measureType': 'Output', 'unitSymbol': 'MW', 'unit': 'MegaWatts', 'measureValue': 1578, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Output_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '1578.35.60', 'deviceLongitude': '1598.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': '3fc4f95f-1a4b-4bac-a619-717cb13f2efc', 'dateTime': '2024-02-13T10:46:26Z', 'deviceId': 'dev-21', 'measureType': 'Rotation Speed', 'unitSymbol': 'RPM', 'unit': 'Revolutions per Minute', 'measureValue': 3007, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Rotation Speed_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '3007.35.60', 'deviceLongitude': '3027.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': 'e7d78c5c-3a68-4833-b713-15df0eab0c6c', 'dateTime': '2024-02-13T10:46:26Z', 'deviceId': 'dev-21', 'measureType': 'Output', 'unitSymbol': 'MW', 'unit': 'MegaWatts', 'measureValue': 1605, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Output_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '1605.35.60', 'deviceLongitude': '1625.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': '1b383106-a2b0-4518-8cd4-efd2d202a883', 'dateTime': '2024-02-13T10:46:26Z', 'deviceId': 'dev-22', 'measureType': 'Rotation Speed', 'unitSymbol': 'RPM', 'unit': 'Revolutions per Minute', 'measureValue': 2991, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Rotation Speed_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '2991.35.60', 'deviceLongitude': '3011.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': '419bee15-64c5-470f-b68e-2cecc96ace2f', 'dateTime': '2024-02-13T10:46:26Z', 'deviceId': 'dev-22', 'measureType': 'Output', 'unitSymbol': 'MW', 'unit': 'MegaWatts', 'measureValue': 1618, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Output_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '1618.35.60', 'deviceLongitude': '1638.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': '8d391db2-56a6-4068-8f98-f3146683c2bd', 'dateTime': '2024-02-13T10:46:27Z', 'deviceId': 'dev-23', 'measureType': 'Rotation Speed', 'unitSymbol': 'RPM', 'unit': 'Revolutions per Minute', 'measureValue': 2925, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Rotation Speed_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '2925.35.60', 'deviceLongitude': '2945.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': 'ca438334-8b08-45a8-8881-54fcc0b6426f', 'dateTime': '2024-02-13T10:46:27Z', 'deviceId': 'dev-23', 'measureType': 'Output', 'unitSymbol': 'MW', 'unit': 'MegaWatts', 'measureValue': 1460, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Output_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '1460.35.60', 'deviceLongitude': '1480.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': '90e94429-95f5-46b8-aa75-667f50840b2e', 'dateTime': '2024-02-13T10:46:27Z', 'deviceId': 'dev-24', 'measureType': 'Rotation Speed', 'unitSymbol': 'RPM', 'unit': 'Revolutions per Minute', 'measureValue': 3099, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Rotation Speed_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '3099.35.60', 'deviceLongitude': '3119.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': '0a196e59-fb97-4be8-b5fc-62a2b2d50eef', 'dateTime': '2024-02-13T10:46:27Z', 'deviceId': 'dev-24', 'measureType': 'Output', 'unitSymbol': 'MW', 'unit': 'MegaWatts', 'measureValue': 1604, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Output_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '1604.35.60', 'deviceLongitude': '1624.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': '604f792c-449d-44f4-b692-2a6360571390', 'dateTime': '2024-02-13T10:46:27Z', 'deviceId': 'dev-25', 'measureType': 'Rotation Speed', 'unitSymbol': 'RPM', 'unit': 'Revolutions per Minute', 'measureValue': 2858, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Rotation Speed_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '2858.35.60', 'deviceLongitude': '2878.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': '6c967c7c-dc5e-46f4-a6fd-e99d370fb00a', 'dateTime': '2024-02-13T10:46:27Z', 'deviceId': 'dev-25', 'measureType': 'Output', 'unitSymbol': 'MW', 'unit': 'MegaWatts', 'measureValue': 1606, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Output_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '1606.35.60', 'deviceLongitude': '1626.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': 'aabc34cf-bc7b-4e73-b5d9-c3112bcf6df3', 'dateTime': '2024-02-13T10:46:27Z', 'deviceId': 'dev-26', 'measureType': 'Rotation Speed', 'unitSymbol': 'RPM', 'unit': 'Revolutions per Minute', 'measureValue': 2901, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Rotation Speed_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '2901.35.60', 'deviceLongitude': '2921.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': '4cd5cea5-7e19-430e-9936-9624bc6ebb2f', 'dateTime': '2024-02-13T10:46:27Z', 'deviceId': 'dev-26', 'measureType': 'Output', 'unitSymbol': 'MW', 'unit': 'MegaWatts', 'measureValue': 1570, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Output_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '1570.35.60', 'deviceLongitude': '1590.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': 'c490c382-7309-4b6e-8d78-741c93c34e51', 'dateTime': '2024-02-13T10:46:27Z', 'deviceId': 'dev-27', 'measureType': 'Rotation Speed', 'unitSymbol': 'RPM', 'unit': 'Revolutions per Minute', 'measureValue': 2762, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Rotation Speed_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '2762.35.60', 'deviceLongitude': '2782.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': 'de6c39eb-cd64-42dc-a1ad-4f671e763fbd', 'dateTime': '2024-02-13T10:46:27Z', 'deviceId': 'dev-27', 'measureType': 'Output', 'unitSymbol': 'MW', 'unit': 'MegaWatts', 'measureValue': 1631, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Output_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '1631.35.60', 'deviceLongitude': '1651.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': 'a6481d0f-45b8-4846-97c4-522dcf78b027', 'dateTime': '2024-02-13T10:46:27Z', 'deviceId': 'dev-28', 'measureType': 'Rotation Speed', 'unitSymbol': 'RPM', 'unit': 'Revolutions per Minute', 'measureValue': 2795, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Rotation Speed_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '2795.35.60', 'deviceLongitude': '2815.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': '6e91fc8b-c7b8-4fb7-810b-5dd6c4da93bb', 'dateTime': '2024-02-13T10:46:27Z', 'deviceId': 'dev-28', 'measureType': 'Output', 'unitSymbol': 'MW', 'unit': 'MegaWatts', 'measureValue': 1405, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Output_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '1405.35.60', 'deviceLongitude': '1425.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': '9bd834c6-b3a1-40fc-ab56-75cc92a66d33', 'dateTime': '2024-02-13T10:46:27Z', 'deviceId': 'dev-29', 'measureType': 'Rotation Speed', 'unitSymbol': 'RPM', 'unit': 'Revolutions per Minute', 'measureValue': 2898, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Rotation Speed_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '2898.35.60', 'deviceLongitude': '2918.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': 'ff05646c-6add-4930-b574-dc1e1bcd916d', 'dateTime': '2024-02-13T10:46:27Z', 'deviceId': 'dev-29', 'measureType': 'Output', 'unitSymbol': 'MW', 'unit': 'MegaWatts', 'measureValue': 1479, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Output_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '1479.35.60', 'deviceLongitude': '1499.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': 'aa310024-143d-4731-93aa-0691c9498090', 'dateTime': '2024-02-13T10:46:27Z', 'deviceId': 'dev-30', 'measureType': 'Rotation Speed', 'unitSymbol': 'RPM', 'unit': 'Revolutions per Minute', 'measureValue': 2971, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Rotation Speed_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '2971.35.60', 'deviceLongitude': '2991.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': '71a95b1e-bc01-464b-a40b-724fc8c81230', 'dateTime': '2024-02-13T10:46:27Z', 'deviceId': 'dev-30', 'measureType': 'Output', 'unitSymbol': 'MW', 'unit': 'MegaWatts', 'measureValue': 1350, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Output_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '1350.35.60', 'deviceLongitude': '1370.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': '0f47ed3e-d8c6-475d-a5ae-3bd47c71e87b', 'dateTime': '2024-02-13T10:46:27Z', 'deviceId': 'dev-31', 'measureType': 'Rotation Speed', 'unitSymbol': 'RPM', 'unit': 'Revolutions per Minute', 'measureValue': 2821, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Rotation Speed_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '2821.35.60', 'deviceLongitude': '2841.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': '1c955e45-5ce2-4df6-9e8f-bbd0c0c97155', 'dateTime': '2024-02-13T10:46:27Z', 'deviceId': 'dev-31', 'measureType': 'Output', 'unitSymbol': 'MW', 'unit': 'MegaWatts', 'measureValue': 1636, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Output_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '1636.35.60', 'deviceLongitude': '1656.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': 'ca0f2759-c3d9-409e-82c0-c5b9b102ca64', 'dateTime': '2024-02-13T10:46:27Z', 'deviceId': 'dev-32', 'measureType': 'Rotation Speed', 'unitSymbol': 'RPM', 'unit': 'Revolutions per Minute', 'measureValue': 2773, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Rotation Speed_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '2773.35.60', 'deviceLongitude': '2793.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': 'c7ae8082-bc3e-4f42-a96c-9c58b8076f83', 'dateTime': '2024-02-13T10:46:27Z', 'deviceId': 'dev-32', 'measureType': 'Output', 'unitSymbol': 'MW', 'unit': 'MegaWatts', 'measureValue': 1601, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Output_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '1601.35.60', 'deviceLongitude': '1621.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': '0bedfdf7-e2dd-4e30-a1fc-7caccd093b1a', 'dateTime': '2024-02-13T10:46:27Z', 'deviceId': 'dev-33', 'measureType': 'Rotation Speed', 'unitSymbol': 'RPM', 'unit': 'Revolutions per Minute', 'measureValue': 3025, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Rotation Speed_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '3025.35.60', 'deviceLongitude': '3045.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': 'cf340483-dd00-4ce6-be41-f94dd6ff10a1', 'dateTime': '2024-02-13T10:46:28Z', 'deviceId': 'dev-33', 'measureType': 'Output', 'unitSymbol': 'MW', 'unit': 'MegaWatts', 'measureValue': 1592, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Output_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '1592.35.60', 'deviceLongitude': '1612.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': 'f3ed5b96-2080-492a-b88b-31f91a607e77', 'dateTime': '2024-02-13T10:46:28Z', 'deviceId': 'dev-34', 'measureType': 'Rotation Speed', 'unitSymbol': 'RPM', 'unit': 'Revolutions per Minute', 'measureValue': 3008, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Rotation Speed_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '3008.35.60', 'deviceLongitude': '3028.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': 'ff223200-bbbe-4a2d-bdff-7ccdb3b7afb1', 'dateTime': '2024-02-13T10:46:28Z', 'deviceId': 'dev-34', 'measureType': 'Output', 'unitSymbol': 'MW', 'unit': 'MegaWatts', 'measureValue': 1556, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Output_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '1556.35.60', 'deviceLongitude': '1576.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': '43e85267-22a2-4f9e-b1c2-035e985120de', 'dateTime': '2024-02-13T10:46:28Z', 'deviceId': 'dev-35', 'measureType': 'Rotation Speed', 'unitSymbol': 'RPM', 'unit': 'Revolutions per Minute', 'measureValue': 3070, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Rotation Speed_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '3070.35.60', 'deviceLongitude': '3090.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# ...
# {'id': '47d06548-9524-45fb-9cee-9bb9e4848600', 'dateTime': '2024-02-13T10:50:34Z', 'deviceId': 'dev-2608', 'measureType': 'Rotation Speed', 'unitSymbol': 'RPM', 'unit': 'Revolutions per Minute', 'measureValue': 2807, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Rotation Speed_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '2807.35.60', 'deviceLongitude': '2827.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': '743c3b03-a7fc-4d52-b52f-85778cbf4907', 'dateTime': '2024-02-13T10:50:34Z', 'deviceId': 'dev-2608', 'measureType': 'Output', 'unitSymbol': 'MW', 'unit': 'MegaWatts', 'measureValue': 1543, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Output_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '1543.35.60', 'deviceLongitude': '1563.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': '40561f23-c804-466c-b4db-a1ba42e7e508', 'dateTime': '2024-02-13T10:50:34Z', 'deviceId': 'dev-2609', 'measureType': 'Rotation Speed', 'unitSymbol': 'RPM', 'unit': 'Revolutions per Minute', 'measureValue': 3084, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Rotation Speed_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '3084.35.60', 'deviceLongitude': '3104.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': '55315854-c3d2-49ef-ab8e-a5db6aa86636', 'dateTime': '2024-02-13T10:50:34Z', 'deviceId': 'dev-2609', 'measureType': 'Output', 'unitSymbol': 'MW', 'unit': 'MegaWatts', 'measureValue': 1374, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Output_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '1374.35.60', 'deviceLongitude': '1394.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': '231c25e7-7937-4a25-8427-b2be38d345ad', 'dateTime': '2024-02-13T10:50:34Z', 'deviceId': 'dev-2610', 'measureType': 'Rotation Speed', 'unitSymbol': 'RPM', 'unit': 'Revolutions per Minute', 'measureValue': 3219, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Rotation Speed_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '3219.35.60', 'deviceLongitude': '3239.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': '8f8f0842-a407-4d61-bcd4-da6963318e0c', 'dateTime': '2024-02-13T10:50:34Z', 'deviceId': 'dev-2610', 'measureType': 'Output', 'unitSymbol': 'MW', 'unit': 'MegaWatts', 'measureValue': 1620, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Output_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '1620.35.60', 'deviceLongitude': '1640.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': '1ce204b0-8cff-4fa9-9ec4-a4fc910d8b00', 'dateTime': '2024-02-13T10:50:34Z', 'deviceId': 'dev-2611', 'measureType': 'Rotation Speed', 'unitSymbol': 'RPM', 'unit': 'Revolutions per Minute', 'measureValue': 2716, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Rotation Speed_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '2716.35.60', 'deviceLongitude': '2736.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': 'b4ad85af-d588-4416-9bbd-d22a6374ea1b', 'dateTime': '2024-02-13T10:50:34Z', 'deviceId': 'dev-2611', 'measureType': 'Output', 'unitSymbol': 'MW', 'unit': 'MegaWatts', 'measureValue': 1352, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Output_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '1352.35.60', 'deviceLongitude': '1372.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': '961c84f9-6b16-4114-a08f-5eac6bfd151b', 'dateTime': '2024-02-13T10:50:34Z', 'deviceId': 'dev-2612', 'measureType': 'Rotation Speed', 'unitSymbol': 'RPM', 'unit': 'Revolutions per Minute', 'measureValue': 3114, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Rotation Speed_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '3114.35.60', 'deviceLongitude': '3134.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': '8905a738-1d83-4eb0-a1ed-062a9bcd30a9', 'dateTime': '2024-02-13T10:50:34Z', 'deviceId': 'dev-2612', 'measureType': 'Output', 'unitSymbol': 'MW', 'unit': 'MegaWatts', 'measureValue': 1569, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Output_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '1569.35.60', 'deviceLongitude': '1589.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': 'fc875a37-5e9e-4aff-b00e-6eccf157ce8f', 'dateTime': '2024-02-13T10:50:34Z', 'deviceId': 'dev-2613', 'measureType': 'Rotation Speed', 'unitSymbol': 'RPM', 'unit': 'Revolutions per Minute', 'measureValue': 3171, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Rotation Speed_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '3171.35.60', 'deviceLongitude': '3191.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': 'e160bc35-627b-46ae-a9d9-6e8a6825a53d', 'dateTime': '2024-02-13T10:50:34Z', 'deviceId': 'dev-2613', 'measureType': 'Output', 'unitSymbol': 'MW', 'unit': 'MegaWatts', 'measureValue': 1531, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Output_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '1531.35.60', 'deviceLongitude': '1551.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': '2f040709-cde3-4709-8347-043e146bac65', 'dateTime': '2024-02-13T10:50:34Z', 'deviceId': 'dev-2614', 'measureType': 'Rotation Speed', 'unitSymbol': 'RPM', 'unit': 'Revolutions per Minute', 'measureValue': 3009, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Rotation Speed_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '3009.35.60', 'deviceLongitude': '3029.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': '44a5ae2c-1248-40e6-a1d9-17456a323e2e', 'dateTime': '2024-02-13T10:50:34Z', 'deviceId': 'dev-2614', 'measureType': 'Output', 'unitSymbol': 'MW', 'unit': 'MegaWatts', 'measureValue': 1459, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Output_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '1459.35.60', 'deviceLongitude': '1479.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': 'd8936326-52ae-41db-89cd-31f33ffaccbb', 'dateTime': '2024-02-13T10:50:34Z', 'deviceId': 'dev-2615', 'measureType': 'Rotation Speed', 'unitSymbol': 'RPM', 'unit': 'Revolutions per Minute', 'measureValue': 3159, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Rotation Speed_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '3159.35.60', 'deviceLongitude': '3179.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': 'd7e26f1e-0069-49a4-9100-fd063a6e8176', 'dateTime': '2024-02-13T10:50:34Z', 'deviceId': 'dev-2615', 'measureType': 'Output', 'unitSymbol': 'MW', 'unit': 'MegaWatts', 'measureValue': 1408, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Output_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '1408.35.60', 'deviceLongitude': '1428.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': '8690c907-8007-4af3-b7bf-c60c05db8873', 'dateTime': '2024-02-13T10:50:34Z', 'deviceId': 'dev-2616', 'measureType': 'Rotation Speed', 'unitSymbol': 'RPM', 'unit': 'Revolutions per Minute', 'measureValue': 2773, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Rotation Speed_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '2773.35.60', 'deviceLongitude': '2793.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': '8061c4ba-92ff-4d6d-aeaa-71445de07936', 'dateTime': '2024-02-13T10:50:34Z', 'deviceId': 'dev-2616', 'measureType': 'Output', 'unitSymbol': 'MW', 'unit': 'MegaWatts', 'measureValue': 1632, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Output_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '1632.35.60', 'deviceLongitude': '1652.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': 'eeb961fd-ac82-472f-a323-a6a2a83f8a18', 'dateTime': '2024-02-13T10:50:34Z', 'deviceId': 'dev-2617', 'measureType': 'Rotation Speed', 'unitSymbol': 'RPM', 'unit': 'Revolutions per Minute', 'measureValue': 2915, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Rotation Speed_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '2915.35.60', 'deviceLongitude': '2935.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': '7c691912-b2fc-418b-a9e8-da0af6a5c383', 'dateTime': '2024-02-13T10:50:35Z', 'deviceId': 'dev-2617', 'measureType': 'Output', 'unitSymbol': 'MW', 'unit': 'MegaWatts', 'measureValue': 1423, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Output_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '1423.35.60', 'deviceLongitude': '1443.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': '8ea85897-7d68-4da4-afaf-de3be99192f5', 'dateTime': '2024-02-13T10:50:35Z', 'deviceId': 'dev-2618', 'measureType': 'Rotation Speed', 'unitSymbol': 'RPM', 'unit': 'Revolutions per Minute', 'measureValue': 2962, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Rotation Speed_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '2962.35.60', 'deviceLongitude': '2982.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': '40fe48cd-cbce-4592-a4a7-9268cab8eb9f', 'dateTime': '2024-02-13T10:50:35Z', 'deviceId': 'dev-2618', 'measureType': 'Output', 'unitSymbol': 'MW', 'unit': 'MegaWatts', 'measureValue': 1459, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Output_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '1459.35.60', 'deviceLongitude': '1479.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
# {'id': '11e8ddb1-3b81-4018-a869-5dd81b16d142', 'dateTime': '2024-02-13T10:50:35Z', 'deviceId': 'dev-2619', 'measureType': 'Rotation Speed', 'unitSymbol': 'RPM', 'unit': 'Revolutions per Minute', 'measureValue': 2709, 'registeredTo': 'Microsoft Corporation - 1 Microsoft Way Redmond WA 98052 USA', 'deviceModel': 'Rotation Speed_001', 'deviceVersion': 'June, 2023', 'deviceLatitude': '2709.35.60', 'deviceLongitude': '2729.35.60', 'deviceOperationalSystemVersion': 'V4 - Created by Rodrigo Souza as a demo for an IoT generator for Azure Cosmos DB.', 'deviceSize': 'The RPM devices have 3 kilos and the size is 50 cm x 65 cm x 30 cm. The MW devices have 6 kilos and the size is 65 cm x 45 cm x 55 cm.'}
